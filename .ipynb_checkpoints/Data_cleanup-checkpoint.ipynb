# %%
import numpy as np
import pandas as pd
import requests
import time
import json
from pprint import pprint
import xmltodict

# %%
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func, inspect
from cryptography.fernet import Fernet

# %% [markdown]
# # NYT Data Extract/Transform

# %%
# API KEY 
ses_api_key = "EH3LYl2x8c4wLClt63RJZGBrZboUE507"

# Best Sellers Lists
nyt_lists_qry = "https://api.nytimes.com/svc/books/v3/lists/names.json?api-key=" + ses_api_key 
nyt_lists_results = requests.get(nyt_lists_qry).json()
nyt_lists_results
nyt_lists_df = pd.DataFrame(nyt_lists_results['results'])

# %%
nyt_lists_df.sort_values(['newest_published_date'], ascending = False)
# Out:
#                                list_name  \
# 0      Combined Print and E-Book Fiction
# 11       Advice How-To and Miscellaneous
# 1   Combined Print and E-Book Nonfiction
# 24                          Series Books
# 23                         Picture Books
# 20      Childrens Middle Grade Hardcover
# 27                 Young Adult Hardcover
# 6                   Paperback Nonfiction
# 2                      Hardcover Fiction
# 3                   Hardcover Nonfiction
# 4                Trade Fiction Paperback
# 31                      Audio Nonfiction
# 53                                Sports
# 52                               Science
# 32                        Business Books
# 30                         Audio Fiction
# 21      Childrens Middle Grade Paperback
# 8                      E-Book Nonfiction
# 28                 Young Adult Paperback
# 26                    Young Adult E-Book
# 7                         E-Book Fiction
# 5                  Mass Market Paperback
# 19         Childrens Middle Grade E-Book
# 14                                 Manga
# 13               Paperback Graphic Books
# 12               Hardcover Graphic Books
# 37                             Espionage
# 51       Religion Spirituality and Faith
# 50                 Race and Civil Rights
# 49             Hardcover Political Books
# 48                                Family
# 46                         Relationships
# 44                                 Humor
# 43                                Health
# 41                  Games and Activities
# 40                      Food and Fitness
# 39           Fashion Manners and Customs
# 38  Expeditions Disasters and Adventures
# 54                                Travel
# 35                               Culture
# 34                  Crime and Punishment
# 33                           Celebrities
# 29                               Animals
# 36                             Education
# 45                  Indigenous Americans
# 25                           Young Adult
# 18                Childrens Middle Grade
# 42              Hardcover Business Books
# 47              Paperback Business Books
# 15                Combined Print Fiction
# 16             Combined Print Nonfiction
# 10                      Paperback Advice
# 9                       Hardcover Advice
# 17                         Chapter Books
# 22                       Paperback Books
#
#                                  display_name  \
# 0             Combined Print & E-Book Fiction
# 11             Advice, How-To & Miscellaneous
# 1          Combined Print & E-Book Nonfiction
# 24                          Children’s Series
# 23                   Children’s Picture Books
# 20          Children’s Middle Grade Hardcover
# 27                      Young Adult Hardcover
# 6                        Paperback Nonfiction
# 2                           Hardcover Fiction
# 3                        Hardcover Nonfiction
# 4                     Paperback Trade Fiction
# 31                           Audio Nonfiction
# 53                         Sports and Fitness
# 52                                    Science
# 32                                   Business
# 30                              Audio Fiction
# 21          Children’s Middle Grade Paperback
# 8                           E-Book Nonfiction
# 28                      Young Adult Paperback
# 26                         Young Adult E-Book
# 7                              E-Book Fiction
# 5               Paperback Mass-Market Fiction
# 19             Children’s Middle Grade E-Book
# 14                                      Manga
# 13                    Paperback Graphic Books
# 12                    Hardcover Graphic Books
# 37                                  Espionage
# 51           Religion, Spirituality and Faith
# 50                      Race and Civil Rights
# 49              Politics and American History
# 48                      Parenthood and Family
# 46                     Love and Relationships
# 44                                      Humor
# 43                                     Health
# 41                       Games and Activities
# 40                              Food and Diet
# 39               Fashion, Manners and Customs
# 38                                Expeditions
# 54                                     Travel
# 35                                    Culture
# 34                       Crime and Punishment
# 33                                Celebrities
# 29                                    Animals
# 36                                  Education
# 45                       Indigenous Americans
# 25                                Young Adult
# 18                    Children’s Middle Grade
# 42                   Hardcover Business Books
# 47                   Paperback Business Books
# 15     Combined Hardcover & Paperback Fiction
# 16  Combined Hardcover & Paperback Nonfiction
# 10                   Paperback Advice & Misc.
# 9                    Hardcover Advice & Misc.
# 17                   Children’s Chapter Books
# 22                 Children’s Paperback Books
#
#                        list_name_encoded oldest_published_date  \
# 0      combined-print-and-e-book-fiction            2011-02-13
# 11       advice-how-to-and-miscellaneous            2013-04-28
# 1   combined-print-and-e-book-nonfiction            2011-02-13
# 24                          series-books            2008-06-08
# 23                         picture-books            2008-06-08
# 20      childrens-middle-grade-hardcover            2015-08-30
# 27                 young-adult-hardcover            2015-08-30
# 6                   paperback-nonfiction            2008-06-08
# 2                      hardcover-fiction            2008-06-08
# 3                   hardcover-nonfiction            2008-06-08
# 4                trade-fiction-paperback            2008-06-08
# 31                      audio-nonfiction            2018-03-11
# 53                                sports            2014-03-02
# 52                               science            2013-04-14
# 32                        business-books            2013-11-03
# 30                         audio-fiction            2018-03-11
# 21      childrens-middle-grade-paperback            2015-08-30
# 8                      e-book-nonfiction            2011-02-13
# 28                 young-adult-paperback            2015-08-30
# 26                    young-adult-e-book            2015-08-30
# 7                         e-book-fiction            2011-02-13
# 5                  mass-market-paperback            2008-06-08
# 19         childrens-middle-grade-e-book            2015-08-30
# 14                                 manga            2009-03-15
# 13               paperback-graphic-books            2009-03-15
# 12               hardcover-graphic-books            2009-03-15
# 37                             espionage            2014-12-14
# 51       religion-spirituality-and-faith            2014-09-07
# 50                 race-and-civil-rights            2014-12-14
# 49             hardcover-political-books            2011-07-03
# 48                                family            2014-09-07
# 46                         relationships            2014-09-07
# 44                                 humor            2014-09-07
# 43                                health            2014-10-12
# 41                  games-and-activities            2014-10-12
# 40                      food-and-fitness            2013-09-01
# 39           fashion-manners-and-customs            2014-10-12
# 38  expeditions-disasters-and-adventures            2014-12-14
# 54                                travel            2014-09-07
# 35                               culture            2014-10-12
# 34                  crime-and-punishment            2014-10-12
# 33                           celebrities            2014-09-07
# 29                               animals            2014-09-07
# 36                             education            2014-10-12
# 45                  indigenous-americans            2014-12-14
# 25                           young-adult            2012-12-16
# 18                childrens-middle-grade            2012-12-16
# 42              hardcover-business-books            2011-07-03
# 47              paperback-business-books            2011-07-03
# 15                combined-print-fiction            2011-02-13
# 16             combined-print-nonfiction            2011-02-13
# 10                      paperback-advice            2008-06-08
# 9                       hardcover-advice            2008-06-08
# 17                         chapter-books            2008-06-08
# 22                       paperback-books            2008-06-08
#
#    newest_published_date  updated
# 0             2019-09-01   WEEKLY
# 11            2019-09-01   WEEKLY
# 1             2019-09-01   WEEKLY
# 24            2019-09-01   WEEKLY
# 23            2019-09-01   WEEKLY
# 20            2019-09-01   WEEKLY
# 27            2019-09-01   WEEKLY
# 6             2019-09-01   WEEKLY
# 2             2019-09-01   WEEKLY
# 3             2019-09-01   WEEKLY
# 4             2019-09-01   WEEKLY
# 31            2019-08-18  MONTHLY
# 53            2019-08-18  MONTHLY
# 52            2019-08-18  MONTHLY
# 32            2019-08-18  MONTHLY
# 30            2019-08-18  MONTHLY
# 21            2017-01-29   WEEKLY
# 8             2017-01-29   WEEKLY
# 28            2017-01-29   WEEKLY
# 26            2017-01-29   WEEKLY
# 7             2017-01-29   WEEKLY
# 5             2017-01-29   WEEKLY
# 19            2017-01-29   WEEKLY
# 14            2017-01-29   WEEKLY
# 13            2017-01-29   WEEKLY
# 12            2017-01-29   WEEKLY
# 37            2017-01-15  MONTHLY
# 51            2017-01-15  MONTHLY
# 50            2017-01-15  MONTHLY
# 49            2017-01-15  MONTHLY
# 48            2017-01-15  MONTHLY
# 46            2017-01-15  MONTHLY
# 44            2017-01-15  MONTHLY
# 43            2017-01-15  MONTHLY
# 41            2017-01-15  MONTHLY
# 40            2017-01-15  MONTHLY
# 39            2017-01-15  MONTHLY
# 38            2017-01-15  MONTHLY
# 54            2017-01-15  MONTHLY
# 35            2017-01-15  MONTHLY
# 34            2017-01-15  MONTHLY
# 33            2017-01-15  MONTHLY
# 29            2017-01-15  MONTHLY
# 36            2017-01-15  MONTHLY
# 45            2016-01-10  MONTHLY
# 25            2015-08-23   WEEKLY
# 18            2015-08-23   WEEKLY
# 42            2013-10-13  MONTHLY
# 47            2013-10-13  MONTHLY
# 15            2013-05-12   WEEKLY
# 16            2013-05-12   WEEKLY
# 10            2013-04-21   WEEKLY
# 9             2013-04-21   WEEKLY
# 17            2012-12-09   WEEKLY
# 22            2012-12-09   WEEKLY

# %%
# Hardcover NONFiction Best Sellers Extract
nyt_h_nfiction_qry = "https://api.nytimes.com/svc/books/v3/lists/current/hardcover-nonfiction.json?api-key=" + ses_api_key 
nyt_h_nfiction_results = requests.get(nyt_h_nfiction_qry).json()
nyt_h_nfiction_results
nyt_h_nfiction = nyt_h_nfiction_results['results']['books']

# %%
# Hardcover NONFiction Transform
nyt_h_nf_df = pd.DataFrame(nyt_h_nfiction)
nyt_h_nf_df = nyt_h_nf_df[['rank','weeks_on_list', 'primary_isbn13', 'publisher', 'book_review_link']]
nyt_h_nf_df = nyt_h_nf_df.rename(columns={'primary_isbn13':'book_id'})
nyt_h_nf_df['book_id']=nyt_h_nf_df['book_id'].astype(np.int64)



category = 'Hardcover Non-Fiction'
nyt_h_nf_df['category'] = category
date = pd.datetime.now()
nyt_h_nf_df['current_as_of_date'] = date

nyt_h_nf_df.head()
# Out:
#    rank  weeks_on_list        book_id         publisher  \
# 0     1             78  9780399590504      Random House
# 1     2              1  9780525509288         One World
# 2     3             40  9781524763138             Crown
# 3     4              6  9781451642292       Avid Reader
# 4     5             15  9781501168680  Simon & Schuster
#
#                                     book_review_link               category  \
# 0  https://www.nytimes.com/2018/03/01/books/revie...  Hardcover Non-Fiction
# 1                                                     Hardcover Non-Fiction
# 2  https://www.nytimes.com/2018/12/06/books/revie...  Hardcover Non-Fiction
# 3  https://www.nytimes.com/2019/06/28/books/revie...  Hardcover Non-Fiction
# 4  https://www.nytimes.com/2019/05/13/books/revie...  Hardcover Non-Fiction
#
#           current_as_of_date
# 0 2019-08-23 10:33:17.342636
# 1 2019-08-23 10:33:17.342636
# 2 2019-08-23 10:33:17.342636
# 3 2019-08-23 10:33:17.342636
# 4 2019-08-23 10:33:17.342636

# %%
# Paperback NONFiction Best Sellers
nyt_p_nfiction_qry = "https://api.nytimes.com/svc/books/v3/lists/current/paperback-nonfiction.json?api-key=" + ses_api_key 
nyt_p_nfiction_results = requests.get(nyt_p_nfiction_qry).json()
nyt_p_nfiction_results
nyt_p_nfiction = nyt_p_nfiction_results['results']['books']

# %%
# Paperback NONFiction Transform
nyt_p_nf_df = pd.DataFrame(nyt_p_nfiction)
nyt_p_nf_df = nyt_p_nf_df[['rank','weeks_on_list', 'primary_isbn13', 'publisher', 'book_review_link']]
nyt_p_nf_df = nyt_p_nf_df.rename(columns={'primary_isbn13':'book_id'})
nyt_p_nf_df['book_id']=nyt_p_nf_df['book_id'].astype(np.int64)

category = 'Paperback Non-Fiction'
nyt_p_nf_df['category'] = category
date = pd.datetime.now()
nyt_p_nf_df['current_as_of_date'] = date

nyt_p_nf_df.head()
# Out:
#    rank  weeks_on_list        book_id         publisher book_review_link  \
# 0     1             27  9780399588198    Spiegel & Grau
# 1     2             66  9780062316110  Harper Perennial
# 2     3             58  9780807047415      Beacon Press
# 3     4            166  9780812984965    Spiegel & Grau
# 4     5             43  9780143127741           Penguin
#
#                 category         current_as_of_date
# 0  Paperback Non-Fiction 2019-08-23 10:33:21.646732
# 1  Paperback Non-Fiction 2019-08-23 10:33:21.646732
# 2  Paperback Non-Fiction 2019-08-23 10:33:21.646732
# 3  Paperback Non-Fiction 2019-08-23 10:33:21.646732
# 4  Paperback Non-Fiction 2019-08-23 10:33:21.646732

# %%
# Hardcover Fiction Best Sellers
nyt_h_fiction_qry = "https://api.nytimes.com/svc/books/v3/lists/current/hardcover-fiction.json?api-key=" + ses_api_key 
nyt_h_fiction_results = requests.get(nyt_h_fiction_qry).json()
nyt_h_fiction_results
nyt_h_fiction = nyt_h_fiction_results['results']['books']

# %%
# Hardcover Fiction Transform
nyt_h_f_df = pd.DataFrame(nyt_h_fiction)
nyt_h_f_df = nyt_h_f_df[['rank','weeks_on_list', 'primary_isbn13', 'publisher', 'book_review_link']]
nyt_h_f_df = nyt_h_f_df.rename(columns={'primary_isbn13':'book_id'})
nyt_h_f_df['book_id']=nyt_h_f_df['book_id'].astype(np.int64)

category = 'Hardcover Fiction'
nyt_h_f_df['category'] = category
date = pd.datetime.now()
nyt_h_f_df['current_as_of_date'] = date

nyt_h_f_df.head()
# Out:
#    rank  weeks_on_list        book_id      publisher  \
# 0     1             50  9780735219090         Putnam
# 1     2              2  9780316527583  Little, Brown
# 2     3              1  9781250051059       Minotaur
# 3     4              4  9781538750568  Grand Central
# 4     5              5  9780385537070      Doubleday
#
#                                     book_review_link           category  \
# 0                                                     Hardcover Fiction
# 1                                                     Hardcover Fiction
# 2                                                     Hardcover Fiction
# 3                                                     Hardcover Fiction
# 4  https://www.nytimes.com/2019/07/11/books/revie...  Hardcover Fiction
#
#           current_as_of_date
# 0 2019-08-23 10:33:25.776511
# 1 2019-08-23 10:33:25.776511
# 2 2019-08-23 10:33:25.776511
# 3 2019-08-23 10:33:25.776511
# 4 2019-08-23 10:33:25.776511

# %%
# Trade Fiction Paperback Best Sellers
nyt_tfp_qry = "https://api.nytimes.com/svc/books/v3/lists/current/trade-fiction-paperback.json?api-key=" + ses_api_key 
nyt_tfp_results = requests.get(nyt_tfp_qry).json()
nyt_tfp_results
nyt_tfp = nyt_tfp_results['results']['books']

# %%
# Trade Fiction Paperback Transform
nyt_tfp_df = pd.DataFrame(nyt_tfp)
nyt_tfp_df = nyt_tfp_df[['rank','weeks_on_list', 'primary_isbn13', 'publisher', 'book_review_link']]
nyt_tfp_df = nyt_tfp_df.rename(columns={'primary_isbn13':'book_id'})
nyt_tfp_df['book_id']=nyt_tfp_df['book_id'].astype(np.int64)

category = 'Trade Fiction Paperback'
nyt_tfp_df['category'] = category
date = pd.datetime.now()
nyt_tfp_df['current_as_of_date'] = date

nyt_tfp_df.head()
# Out:
#    rank  weeks_on_list        book_id         publisher  \
# 0     1            164  9780062364913  Harper Perennial
# 1     2             50  9780062797155            Harper
# 2     3             15  9780735224315           Penguin
# 3     4              2  9781400033416           Vintage
# 4     5             13  9780425284704        Ballantine
#
#                                     book_review_link                 category  \
# 0                                                     Trade Fiction Paperback
# 1  https://www.nytimes.com/2018/11/16/books/revie...  Trade Fiction Paperback
# 2  https://www.nytimes.com/2017/09/25/books/revie...  Trade Fiction Paperback
# 3  https://www.nytimes.com/1987/09/02/books/books...  Trade Fiction Paperback
# 4                                                     Trade Fiction Paperback
#
#           current_as_of_date
# 0 2019-08-23 10:34:00.649322
# 1 2019-08-23 10:34:00.649322
# 2 2019-08-23 10:34:00.649322
# 3 2019-08-23 10:34:00.649322
# 4 2019-08-23 10:34:00.649322

# %%
# YA Hardcover Best Sellers
nyt_ya_qry = "https://api.nytimes.com/svc/books/v3/lists/current/young-adult-hardcover.json?api-key=" + ses_api_key 
nyt_ya_results = requests.get(nyt_ya_qry).json()
nyt_ya_results
nyt_ya = nyt_ya_results['results']['books']

# %%
nyt_ya_results
# Out:
# {'status': 'OK',
#  'copyright': 'Copyright (c) 2019 The New York Times Company.  All Rights Reserved.',
#  'num_results': 10,
#  'last_modified': '2019-08-23T15:01:05-04:00',
#  'results': {'list_name': 'Young Adult Hardcover',
#   'list_name_encoded': 'young-adult-hardcover',
#   'bestsellers_date': '2019-08-17',
#   'published_date': '2019-09-01',
#   'published_date_description': 'latest',
#   'next_published_date': '',
#   'previous_published_date': '2019-08-25',
#   'display_name': 'Young Adult Hardcover',
#   'normal_list_ends_at': 10,
#   'updated': 'WEEKLY',
#   'books': [{'rank': 1,
#     'rank_last_week': 1,
#     'weeks_on_list': 129,
#     'asterisk': 0,
#     'dagger': 0,
#     'primary_isbn10': '0062498533',
#     'primary_isbn13': '9780062498533',
#     'publisher': 'Balzer + Bray',
#     'description': 'A 16-year-old girl sees a police officer kill her friend.',
#     'price': 0,
#     'title': 'THE HATE U GIVE',
#     'author': 'Angie Thomas',
#     'contributor': 'by Angie Thomas',
#     'contributor_note': '',
#     'book_image': 'https://s1.nyt.com/du/books/images/9780062498533.jpg',
#     'book_image_width': 328,
#     'book_image_height': 495,
#     'amazon_product_url': 'https://www.amazon.com/Hate-U-Give-Angie-Thomas/dp/0062498533?tag=NYTBS-20',
#     'age_group': '',
#     'book_review_link': '',
#     'first_chapter_link': '',
#     'sunday_review_link': '',
#     'article_chapter_link': '',
#     'isbns': [{'isbn10': '0062498533', 'isbn13': '9780062498533'},
#      {'isbn10': '1432841696', 'isbn13': '9781432841690'},
#      {'isbn10': '0062871358', 'isbn13': '9780062871350'},
#      {'isbn10': '0062872346', 'isbn13': '9780062872340'}],
#     'buy_links': [{'name': 'Local Booksellers',
#       'url': 'http://www.indiebound.org/book/9780062498533?aff=NYT'},
#      {'name': 'Barnes and Noble',
#       'url': 'http://www.anrdoezrs.net/click-7990613-11819508?url=http%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9780062498533'},
#      {'name': 'Amazon',
#       'url': 'https://www.amazon.com/Hate-U-Give-Angie-Thomas/dp/0062498533?tag=NYTBS-20'}],
#     'book_uri': 'nyt://book/42eef418-b5f3-5534-ac24-5edc53a4e5a6'},
#    {'rank': 2,
#     'rank_last_week': 2,
#     'weeks_on_list': 37,
#     'asterisk': 0,
#     'dagger': 0,
#     'primary_isbn10': '1534451560',
#     'primary_isbn13': '9781534451568',
#     'publisher': 'Simon & Schuster',
#     'description': "Stella and Will are in love, but they can't get within five feet of each other.",
#     'price': 0,
#     'title': 'FIVE FEET APART',
#     'author': 'Rachael Lippincott with Mikki Daughtry and Tobias Iaconis',
#     'contributor': 'by Rachael Lippincott with Mikki Daughtry and Tobias Iaconis',
#     'contributor_note': '',
#     'book_image': 'https://s1.nyt.com/du/books/images/9781534437333.jpg',
#     'book_image_width': 328,
#     'book_image_height': 495,
#     'amazon_product_url': 'https://www.amazon.com/Five-Feet-Apart-Rachael-Lippincott/dp/1534437339?tag=NYTBS-20',
#     'age_group': '',
#     'book_review_link': '',
#     'first_chapter_link': '',
#     'sunday_review_link': '',
#     'article_chapter_link': '',
#     'isbns': [{'isbn10': '1534437339', 'isbn13': '9781534437333'},
#      {'isbn10': '1534451560', 'isbn13': '9781534451568'}],
#     'buy_links': [{'name': 'Local Booksellers',
#       'url': 'http://www.indiebound.org/book/9781534451568?aff=NYT'},
#      {'name': 'Barnes and Noble',
#       'url': 'http://www.anrdoezrs.net/click-7990613-11819508?url=http%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9781534451568'},
#      {'name': 'Amazon',
#       'url': 'https://www.amazon.com/Five-Feet-Apart-Rachael-Lippincott/dp/1534437339?tag=NYTBS-20'}],
#     'book_uri': 'nyt://book/d098ac6c-71df-5286-bab4-9898938641a8'},
#    {'rank': 3,
#     'rank_last_week': 0,
#     'weeks_on_list': 17,
#     'asterisk': 0,
#     'dagger': 0,
#     'primary_isbn10': '0062662805',
#     'primary_isbn13': '9780062662804',
#     'publisher': 'HarperTeen',
#     'description': 'A coming-of-age story told in verse.',
#     'price': 0,
#     'title': 'THE POET X',
#     'author': 'Elizabeth Acevedo',
#     'contributor': 'by Elizabeth Acevedo',
#     'contributor_note': '',
#     'book_image': 'https://s1.nyt.com/du/books/images/9780062662804.jpg',
#     'book_image_width': 327,
#     'book_image_height': 495,
#     'amazon_product_url': 'https://www.amazon.com/Poet-X-Elizabeth-Acevedo/dp/0062662805?tag=NYTBS-20',
#     'age_group': '',
#     'book_review_link': '',
#     'first_chapter_link': '',
#     'sunday_review_link': '',
#     'article_chapter_link': '',
#     'isbns': [{'isbn10': '0062662805', 'isbn13': '9780062662804'}],
#     'buy_links': [{'name': 'Local Booksellers',
#       'url': 'http://www.indiebound.org/book/9780062662804?aff=NYT'},
#      {'name': 'Barnes and Noble',
#       'url': 'http://www.anrdoezrs.net/click-7990613-11819508?url=http%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9780062662804'},
#      {'name': 'Amazon',
#       'url': 'https://www.amazon.com/Poet-X-Elizabeth-Acevedo/dp/0062662805?tag=NYTBS-20'}],
#     'book_uri': 'nyt://book/df2475c7-1a4b-590e-866d-806fc904e574'},
#    {'rank': 4,
#     'rank_last_week': 5,
#     'weeks_on_list': 76,
#     'asterisk': 0,
#     'dagger': 0,
#     'primary_isbn10': '1250170974',
#     'primary_isbn13': '9781250170972',
#     'publisher': 'Holt',
#     'description': 'Zélie fights to restore magic to the land of Orïsha.',
#     'price': 0,
#     'title': 'CHILDREN OF BLOOD AND BONE',
#     'author': 'Tomi Adeyemi',
#     'contributor': 'by Tomi Adeyemi',
#     'contributor_note': '',
#     'book_image': 'https://s1.nyt.com/du/books/images/9781250170972.jpg',
#     'book_image_width': 330,
#     'book_image_height': 495,
#     'amazon_product_url': 'https://www.amazon.com/Children-Blood-Bone-Legacy-Orisha/dp/1250170974?tag=NYTBS-20',
#     'age_group': '',
#     'book_review_link': '',
#     'first_chapter_link': '',
#     'sunday_review_link': '',
#     'article_chapter_link': '',
#     'isbns': [{'isbn10': '1250170974', 'isbn13': '9781250170972'}],
#     'buy_links': [{'name': 'Local Booksellers',
#       'url': 'http://www.indiebound.org/book/9781250170972?aff=NYT'},
#      {'name': 'Barnes and Noble',
#       'url': 'http://www.anrdoezrs.net/click-7990613-11819508?url=http%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9781250170972'},
#      {'name': 'Amazon',
#       'url': 'https://www.amazon.com/Children-Blood-Bone-Legacy-Orisha/dp/1250170974?tag=NYTBS-20'}],
#     'book_uri': 'nyt://book/3701bd4b-60ad-5424-b7d6-c7bf3de319e1'},
#    {'rank': 5,
#     'rank_last_week': 8,
#     'weeks_on_list': 87,
#     'asterisk': 0,
#     'dagger': 0,
#     'primary_isbn10': '1524714682',
#     'primary_isbn13': '9781524714680',
#     'publisher': 'Delacorte',
#     'description': 'For five students, a detour into detention ends in murder.',
#     'price': 0,
#     'title': 'ONE OF US IS LYING',
#     'author': 'Karen M McManus',
#     'contributor': 'by Karen M. McManus',
#     'contributor_note': '',
#     'book_image': 'https://s1.nyt.com/du/books/images/9781524714680.jpg',
#     'book_image_width': 327,
#     'book_image_height': 495,
#     'amazon_product_url': 'https://www.amazon.com/One-Us-Lying-Karen-McManus/dp/1524714682?tag=NYTBS-20',
#     'age_group': '',
#     'book_review_link': '',
#     'first_chapter_link': '',
#     'sunday_review_link': '',
#     'article_chapter_link': '',
#     'isbns': [{'isbn10': '1524714682', 'isbn13': '9781524714680'},
#      {'isbn10': '1524714690', 'isbn13': '9781524714697'}],
#     'buy_links': [{'name': 'Local Booksellers',
#       'url': 'http://www.indiebound.org/book/9781524714680?aff=NYT'},
#      {'name': 'Barnes and Noble',
#       'url': 'http://www.anrdoezrs.net/click-7990613-11819508?url=http%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9781524714680'},
#      {'name': 'Amazon',
#       'url': 'https://www.amazon.com/One-Us-Lying-Karen-McManus/dp/1524714682?tag=NYTBS-20'}],
#     'book_uri': 'nyt://book/68977997-3f85-5971-aca2-e80f543b2814'},
#    {'rank': 6,
#     'rank_last_week': 3,
#     'weeks_on_list': 28,
#     'asterisk': 0,
#     'dagger': 0,
#     'primary_isbn10': 'None',
#     'primary_isbn13': '9780062498564',
#     'publisher': 'Balzer + Bray',
#     'description': 'Bri strives to become a hip-hop star despite numerous obstacles.',
#     'price': 0,
#     'title': 'ON THE COME UP',
#     'author': 'Angie Thomas',
#     'contributor': 'by Angie Thomas',
#     'contributor_note': '',
#     'book_image': 'https://s1.nyt.com/du/books/images/9780062498564.jpg',
#     'book_image_width': 329,
#     'book_image_height': 499,
#     'amazon_product_url': 'https://www.amazon.com/Come-Up-Angie-Thomas/dp/0062498568?tag=NYTBS-20',
#     'age_group': '',
#     'book_review_link': '',
#     'first_chapter_link': '',
#     'sunday_review_link': '',
#     'article_chapter_link': '',
#     'isbns': [],
#     'buy_links': [{'name': 'Local Booksellers',
#       'url': 'http://www.indiebound.org/book/9780062498564?aff=NYT'},
#      {'name': 'Barnes and Noble',
#       'url': 'http://www.anrdoezrs.net/click-7990613-11819508?url=http%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9780062498564'},
#      {'name': 'Amazon',
#       'url': 'https://www.amazon.com/Come-Up-Angie-Thomas/dp/0062498568?tag=NYTBS-20'}],
#     'book_uri': 'nyt://book/721587f4-5b6c-5f6d-929b-cf7a60b220c3'},
#    {'rank': 7,
#     'rank_last_week': 4,
#     'weeks_on_list': 11,
#     'asterisk': 0,
#     'dagger': 0,
#     'primary_isbn10': '0062933620',
#     'primary_isbn13': '9780062933621',
#     'publisher': 'Balzer + Bray',
#     'description': "Emma Saylor falls in love when she spends the summer with her deceased mother's family.",
#     'price': 0,
#     'title': 'THE REST OF THE STORY',
#     'author': 'Sarah Dessen',
#     'contributor': 'by Sarah Dessen',
#     'contributor_note': '',
#     'book_image': 'https://s1.nyt.com/du/books/images/9780062933621.jpg',
#     'book_image_width': 328,
#     'book_image_height': 495,
#     'amazon_product_url': 'https://www.amazon.com/Rest-Story-Sarah-Dessen/dp/0062933620?tag=NYTBS-20',
#     'age_group': '',
#     'book_review_link': '',
#     'first_chapter_link': '',
#     'sunday_review_link': '',
#     'article_chapter_link': '',
#     'isbns': [{'isbn10': '0062933620', 'isbn13': '9780062933621'}],
#     'buy_links': [{'name': 'Local Booksellers',
#       'url': 'http://www.indiebound.org/book/9780062933621?aff=NYT'},
#      {'name': 'Barnes and Noble',
#       'url': 'http://www.anrdoezrs.net/click-7990613-11819508?url=http%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9780062933621'},
#      {'name': 'Amazon',
#       'url': 'https://www.amazon.com/Rest-Story-Sarah-Dessen/dp/0062933620?tag=NYTBS-20'}],
#     'book_uri': 'nyt://book/0e3bedc7-c481-5235-bf9d-118f91215125'},
#    {'rank': 8,
#     'rank_last_week': 9,
#     'weeks_on_list': 11,
#     'asterisk': 0,
#     'dagger': 0,
#     'primary_isbn10': '1534433627',
#     'primary_isbn13': '9781534433625',
#     'publisher': 'Margaret K. McElderry',
#     'description': 'A companion to the Mortal Instruments, the Infernal Devices and the Dark Artifices series.',
#     'price': 0,
#     'title': 'GHOSTS OF THE SHADOW MARKET',
#     'author': 'Cassandra Clare, Sarah Rees Brennan, Maureen Johnson, Kelly Link and Robin Wasserman',
#     'contributor': 'by Cassandra Clare, Sarah Rees Brennan, Maureen Johnson, Kelly Link and Robin Wasserman',
#     'contributor_note': '',
#     'book_image': 'https://s1.nyt.com/du/books/images/9781534433625.jpg',
#     'book_image_width': 328,
#     'book_image_height': 495,
#     'amazon_product_url': 'https://www.amazon.com/Ghosts-Shadow-Market-Cassandra-Clare/dp/1534433627?tag=NYTBS-20',
#     'age_group': '',
#     'book_review_link': '',
#     'first_chapter_link': '',
#     'sunday_review_link': '',
#     'article_chapter_link': '',
#     'isbns': [{'isbn10': '1534433627', 'isbn13': '9781534433625'}],
#     'buy_links': [{'name': 'Local Booksellers',
#       'url': 'http://www.indiebound.org/book/9781534433625?aff=NYT'},
#      {'name': 'Barnes and Noble',
#       'url': 'http://www.anrdoezrs.net/click-7990613-11819508?url=http%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9781534433625'},
#      {'name': 'Amazon',
#       'url': 'https://www.amazon.com/Ghosts-Shadow-Market-Cassandra-Clare/dp/1534433627?tag=NYTBS-20'}],
#     'book_uri': 'nyt://book/b7877908-38db-58ad-8283-b2644a3ca7ec'},
#    {'rank': 9,
#     'rank_last_week': 7,
#     'weeks_on_list': 14,
#     'asterisk': 0,
#     'dagger': 0,
#     'primary_isbn10': '006266283X',
#     'primary_isbn13': '9780062662835',
#     'publisher': 'HarperTeen',
#     'description': 'Emoni juggles school, work and motherhood while pursuing her dream to become a chef.',
#     'price': 0,
#     'title': 'WITH THE FIRE ON HIGH',
#     'author': 'Elizabeth Acevedo',
#     'contributor': 'by Elizabeth Acevedo',
#     'contributor_note': '',
#     'book_image': 'https://s1.nyt.com/du/books/images/9780062662835.jpg',
#     'book_image_width': 328,
#     'book_image_height': 495,
#     'amazon_product_url': 'https://www.amazon.com/Fire-High-Elizabeth-Acevedo/dp/006266283X?tag=NYTBS-20',
#     'age_group': '',
#     'book_review_link': 'https://www.nytimes.com/2019/05/08/books/review/elizabeth-acevedo-with-the-fire-on-high.html',
#     'first_chapter_link': '',
#     'sunday_review_link': '',
#     'article_chapter_link': '',
#     'isbns': [{'isbn10': '006266283X', 'isbn13': '9780062662835'}],
#     'buy_links': [{'name': 'Local Booksellers',
#       'url': 'http://www.indiebound.org/book/9780062662835?aff=NYT'},
#      {'name': 'Barnes and Noble',
#       'url': 'http://www.anrdoezrs.net/click-7990613-11819508?url=http%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9780062662835'},
#      {'name': 'Amazon',
#       'url': 'https://www.amazon.com/Fire-High-Elizabeth-Acevedo/dp/006266283X?tag=NYTBS-20'}],
#     'book_uri': 'nyt://book/faca4d9c-eca2-5218-8fce-28ee118e7936'},
#    {'rank': 10,
#     'rank_last_week': 0,
#     'weeks_on_list': 1,
#     'asterisk': 0,
#     'dagger': 0,
#     'primary_isbn10': '1984831925',
#     'primary_isbn13': '9781984831927',
#     'publisher': 'Delacorte',
#     'description': 'Annaleigh tries to unravel the darkness that has fallen over her family.',
#     'price': 0,
#     'title': 'HOUSE OF SALT AND SORROWS',
#     'author': 'Erin A Craig',
#     'contributor': 'by Erin A. Craig',
#     'contributor_note': '',
#     'book_image': 'https://s1.nyt.com/du/books/images/9781984831927.jpg',
#     'book_image_width': 327,
#     'book_image_height': 495,
#     'amazon_product_url': 'https://www.amazon.com/House-Salt-Sorrows-Erin-Craig/dp/1984831925?tag=NYTBS-20',
#     'age_group': '',
#     'book_review_link': '',
#     'first_chapter_link': '',
#     'sunday_review_link': '',
#     'article_chapter_link': '',
#     'isbns': [{'isbn10': '1984831925', 'isbn13': '9781984831927'}],
#     'buy_links': [{'name': 'Local Booksellers',
#       'url': 'http://www.indiebound.org/book/9781984831927?aff=NYT'},
#      {'name': 'Barnes and Noble',
#       'url': 'http://www.anrdoezrs.net/click-7990613-11819508?url=http%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9781984831927'},
#      {'name': 'Amazon',
#       'url': 'https://www.amazon.com/House-Salt-Sorrows-Erin-Craig/dp/1984831925?tag=NYTBS-20'}],
#     'book_uri': 'nyt://book/85ffdb20-d0cd-51ee-9f23-9e19c7fef98f'}],
#   'corrections': []}}

# %%
# YA Hardcover Transform
nyt_ya_df = pd.DataFrame(nyt_ya)
nyt_ya_df = nyt_ya_df[['rank','weeks_on_list', 'primary_isbn13', 'publisher', 'book_review_link']]
nyt_ya_df = nyt_ya_df.rename(columns={'primary_isbn13':'book_id'})
nyt_ya_df['book_id']=nyt_ya_df['book_id'].astype(np.int64)

category = 'YA Hardcover'
nyt_ya_df['category'] = category
date = pd.datetime.now()
nyt_ya_df['current_as_of_date'] = date

nyt_ya_df.head()
# Out:
#    rank  weeks_on_list        book_id         publisher book_review_link  \
# 0     1            129  9780062498533     Balzer + Bray
# 1     2             37  9781534451568  Simon & Schuster
# 2     3             17  9780062662804        HarperTeen
# 3     4             76  9781250170972              Holt
# 4     5             87  9781524714680         Delacorte
#
#        category         current_as_of_date
# 0  YA Hardcover 2019-08-23 10:34:06.689920
# 1  YA Hardcover 2019-08-23 10:34:06.689920
# 2  YA Hardcover 2019-08-23 10:34:06.689920
# 3  YA Hardcover 2019-08-23 10:34:06.689920
# 4  YA Hardcover 2019-08-23 10:34:06.689920

# %%
nyt_books = pd.concat([nyt_h_nf_df, nyt_p_nf_df, nyt_h_f_df, nyt_tfp_df, nyt_ya_df]).reset_index()
del nyt_books['index']
nyt_books.index.name = 'reviews_id'
nyt_books.head()
# Out:
#             rank  weeks_on_list        book_id         publisher  \
# reviews_id
# 0              1             78  9780399590504      Random House
# 1              2              1  9780525509288         One World
# 2              3             40  9781524763138             Crown
# 3              4              6  9781451642292       Avid Reader
# 4              5             15  9781501168680  Simon & Schuster
#
#                                              book_review_link  \
# reviews_id
# 0           https://www.nytimes.com/2018/03/01/books/revie...
# 1
# 2           https://www.nytimes.com/2018/12/06/books/revie...
# 3           https://www.nytimes.com/2019/06/28/books/revie...
# 4           https://www.nytimes.com/2019/05/13/books/revie...
#
#                          category         current_as_of_date
# reviews_id
# 0           Hardcover Non-Fiction 2019-08-23 10:33:17.342636
# 1           Hardcover Non-Fiction 2019-08-23 10:33:17.342636
# 2           Hardcover Non-Fiction 2019-08-23 10:33:17.342636
# 3           Hardcover Non-Fiction 2019-08-23 10:33:17.342636
# 4           Hardcover Non-Fiction 2019-08-23 10:33:17.342636

# %% [markdown]
# # Goodreads Data Extract/Transform

# %%
import pandas as pd
from sqlalchemy import create_engine
import numpy as np

# %%
# Import CSV

books_csv = "books.csv"
booksdata = pd.read_csv(books_csv, error_bad_lines=False)
booksdata.head()
# Out:
#    bookID                                              title  \
# 0     1.0  Harry Potter and the Half-Blood Prince (Harry ...
# 1     2.0  Harry Potter and the Order of the Phoenix (Har...
# 2     3.0  Harry Potter and the Sorcerer's Stone (Harry P...
# 3     4.0  Harry Potter and the Chamber of Secrets (Harry...
# 4     5.0  Harry Potter and the Prisoner of Azkaban (Harr...
#
#                       authors  average_rating        isbn        isbn13  \
# 0  J.K. Rowling-Mary GrandPré            4.56   439785960  9.780000e+12
# 1  J.K. Rowling-Mary GrandPré            4.49   439358078  9.780000e+12
# 2  J.K. Rowling-Mary GrandPré            4.47   439554934  9.780000e+12
# 3                J.K. Rowling            4.41   439554896  9.780000e+12
# 4  J.K. Rowling-Mary GrandPré            4.55  043965548X  9.780000e+12
#
#   language_code  # num_pages  ratings_count  text_reviews_count  Unnamed: 10
# 0           eng        652.0      1944099.0             26249.0          NaN
# 1           eng        870.0      1996446.0             27613.0          NaN
# 2           eng        320.0      5629932.0             70390.0          NaN
# 3           eng        352.0         6267.0               272.0          NaN
# 4           eng        435.0      2149872.0             33964.0          NaN

# %%
# Clean database (booksID from isbn13, title, authors)

booksDB = booksdata[["isbn13", "title", "authors"]]
booksDB = booksDB.rename(columns={"isbn13": "book_id",
                                    "title": "title",
                                    "authors": "authors"})
booksDB.head()
# Out:
#         book_id                                              title  \
# 0  9.780000e+12  Harry Potter and the Half-Blood Prince (Harry ...
# 1  9.780000e+12  Harry Potter and the Order of the Phoenix (Har...
# 2  9.780000e+12  Harry Potter and the Sorcerer's Stone (Harry P...
# 3  9.780000e+12  Harry Potter and the Chamber of Secrets (Harry...
# 4  9.780000e+12  Harry Potter and the Prisoner of Azkaban (Harr...
#
#                       authors
# 0  J.K. Rowling-Mary GrandPré
# 1  J.K. Rowling-Mary GrandPré
# 2  J.K. Rowling-Mary GrandPré
# 3                J.K. Rowling
# 4  J.K. Rowling-Mary GrandPré

# %%
# Connect to Postgres

database = "booksETL"
engine = create_engine('postgres://postgres:postgres@localhost:5432/booksETL')
connection = engine.connect()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\envs\PythonDat37\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2261         try:
# -> 2262             return fn()
#    2263         except dialect.dbapi.Error as e:
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonDat37\lib\site-packages\sqlalchemy\pool\base.py in unique_connection(self)
#     302         """
# --> 303         return _ConnectionFairy._checkout(self)
#     304
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonDat37\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     759         if not fairy:
# --> 760             fairy = _ConnectionRecord.checkout(pool)
#     761
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonDat37\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     491     def checkout(cls, pool):
# --> 492         rec = pool._do_get()
#     493         try:
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonDat37\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     138                 with util.safe_reraise():
# --> 139                     self._dec_overflow()
#     140         else:
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonDat37\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      67             if not self.warn_only:
# ---> 68                 compat.reraise(exc_type, exc_value, exc_tb)
#      69         else:
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonDat37\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     153             raise value.with_traceback(tb)
# --> 154         raise value
#     155
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonDat37\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     135             try:
# --> 136                 return self._create_connection()
#     137             except:
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonDat37\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     307
# --> 308         return _ConnectionRecord(self)
#     309
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonDat37\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     436         if connect:
# --> 437             self.__connect(first_connect_check=True)
#     438         self.finalize_callback = deque()
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonDat37\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     638             self.starttime = time.time()
# --> 639             connection = pool._invoke_creator(self)
#     640             pool.logger.debug("Created new connection %r", connection)
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonDat37\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonDat37\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     450     def connect(self, *cargs, **cparams):
# --> 451         return self.dbapi.connect(*cargs, **cparams)
#     452
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonDat37\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     125     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 126     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     127     if cursor_factory is not None:
#
# OperationalError: FATAL:  password authentication failed for user "postgres"
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-156-e98b3c0c90b1> in <module>
#       3 database = "booksETL"
#       4 engine = create_engine('postgres://postgres:postgres@localhost:5432/booksETL')
# ----> 5 connection = engine.connect()
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonDat37\lib\site-packages\sqlalchemy\engine\base.py in connect(self, **kwargs)
#    2191         """
#    2192
# -> 2193         return self._connection_cls(self, **kwargs)
#    2194
#    2195     @util.deprecated(
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonDat37\lib\site-packages\sqlalchemy\engine\base.py in __init__(self, engine, connection, close_with_result, _branch_from, _execution_options, _dispatch, _has_events)
#     101                 connection
#     102                 if connection is not None
# --> 103                 else engine.raw_connection()
#     104             )
#     105             self.__transaction = None
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonDat37\lib\site-packages\sqlalchemy\engine\base.py in raw_connection(self, _connection)
#    2291         """
#    2292         return self._wrap_pool_connect(
# -> 2293             self.pool.unique_connection, _connection
#    2294         )
#    2295
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonDat37\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2264             if connection is None:
#    2265                 Connection._handle_dbapi_exception_noconnection(
# -> 2266                     e, dialect, self
#    2267                 )
#    2268             else:
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonDat37\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1534             util.raise_from_cause(newraise, exc_info)
#    1535         elif should_wrap:
# -> 1536             util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1537         else:
#    1538             util.reraise(*exc_info)
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonDat37\lib\site-packages\sqlalchemy\util\compat.py in raise_from_cause(exception, exc_info)
#     397     exc_type, exc_value, exc_tb = exc_info
#     398     cause = exc_value if exc_value is not exception else None
# --> 399     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     400
#     401
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonDat37\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     151             value.__cause__ = cause
#     152         if value.__traceback__ is not tb:
# --> 153             raise value.with_traceback(tb)
#     154         raise value
#     155
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonDat37\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2260         dialect = self.dialect
#    2261         try:
# -> 2262             return fn()
#    2263         except dialect.dbapi.Error as e:
#    2264             if connection is None:
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonDat37\lib\site-packages\sqlalchemy\pool\base.py in unique_connection(self)
#     301
#     302         """
# --> 303         return _ConnectionFairy._checkout(self)
#     304
#     305     def _create_connection(self):
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonDat37\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     758     def _checkout(cls, pool, threadconns=None, fairy=None):
#     759         if not fairy:
# --> 760             fairy = _ConnectionRecord.checkout(pool)
#     761
#     762             fairy._pool = pool
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonDat37\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     490     @classmethod
#     491     def checkout(cls, pool):
# --> 492         rec = pool._do_get()
#     493         try:
#     494             dbapi_connection = rec.get_connection()
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonDat37\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     137             except:
#     138                 with util.safe_reraise():
# --> 139                     self._dec_overflow()
#     140         else:
#     141             return self._do_get()
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonDat37\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      66             self._exc_info = None  # remove potential circular references
#      67             if not self.warn_only:
# ---> 68                 compat.reraise(exc_type, exc_value, exc_tb)
#      69         else:
#      70             if not compat.py3k and self._exc_info and self._exc_info[1]:
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonDat37\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     152         if value.__traceback__ is not tb:
#     153             raise value.with_traceback(tb)
# --> 154         raise value
#     155
#     156     def u(s):
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonDat37\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     134         if self._inc_overflow():
#     135             try:
# --> 136                 return self._create_connection()
#     137             except:
#     138                 with util.safe_reraise():
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonDat37\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     306         """Called by subclasses to create a new ConnectionRecord."""
#     307
# --> 308         return _ConnectionRecord(self)
#     309
#     310     def _invalidate(self, connection, exception=None, _checkin=True):
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonDat37\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     435         self.__pool = pool
#     436         if connect:
# --> 437             self.__connect(first_connect_check=True)
#     438         self.finalize_callback = deque()
#     439
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonDat37\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     637         try:
#     638             self.starttime = time.time()
# --> 639             connection = pool._invoke_creator(self)
#     640             pool.logger.debug("Created new connection %r", connection)
#     641             self.connection = connection
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonDat37\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     112                         if connection is not None:
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#     116             creator = pop_kwarg("creator", connect)
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonDat37\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     449
#     450     def connect(self, *cargs, **cparams):
# --> 451         return self.dbapi.connect(*cargs, **cparams)
#     452
#     453     def create_connect_args(self, url):
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonDat37\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     124
#     125     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 126     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     127     if cursor_factory is not None:
#     128         conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) FATAL:  password authentication failed for user "postgres"
#
# (Background on this error at: http://sqlalche.me/e/e3q8)

# %%
# Confirm tables

engine.table_names()
# Out:
# ['books']

# %%
# Load titles into books table

booksDB.to_sql(name='books', con=engine, if_exists='append', index=False)

# %% [markdown]
# # PenguinRH Data Extract/Transform

# %%
import xml.etree.ElementTree as ET
from collections import OrderedDict
url = 'https://reststop.randomhouse.com/resources/authorevents/?start=0&max=0&expandLevel=1'

response = requests.get(url)

root = ET.fromstring(response.content)

# %%
for child in root.iter('*'):
    print(child.tag)
# Out:
# authorevents
# authorEvent
# address1
# authorid
# city
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# authorEvent
# address1
# authorid
# city
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# eventtime
# isbn
# isbn10
# market
# state
# status
# telephone
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# eventtime
# isbn
# isbn10
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# authorid
# city
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# authorEvent
# address1
# authorid
# city
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# authorEvent
# address1
# authorid
# city
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# telephone
# zip
# authorEvent
# address1
# authorid
# city
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# city
# description
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# telephone
# zip
# authorEvent
# city
# description
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# authorEvent
# address1
# authorid
# city
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# authorEvent
# address1
# authorid
# city
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# telephone
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# authorEvent
# address1
# authorid
# city
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# authorid
# city
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# authorEvent
# address1
# authorid
# city
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# telephone
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# authorEvent
# address1
# authorid
# city
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# authorEvent
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# telephone
# authorEvent
# address1
# authorid
# city
# eventauthor
# eventdate
# eventdateend
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# authorEvent
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# market
# state
# status
# authorEvent
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# market
# state
# status
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# telephone
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# eventauthor
# eventdate
# eventdateend
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# comments
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# telephone
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# telephone
# zip
# authorEvent
# address1
# authorid
# city
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# eventauthor
# eventdate
# eventdateend
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# eventauthor
# eventdate
# eventdateend
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# eventauthor
# eventdate
# eventdateend
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# eventauthor
# eventdate
# eventdateend
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# telephone
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# telephone
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# telephone
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# telephone
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# telephone
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# authorid
# city
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# telephone
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# authorid
# city
# eventauthor
# eventdate
# eventdateend
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# telephone
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# telephone
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# telephone
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# telephone
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# authorid
# city
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# telephone
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# eventauthor
# eventdate
# eventdateend
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# telephone
# zip
# authorEvent
# address1
# authorid
# city
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# telephone
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# telephone
# zip
# authorEvent
# address1
# authorid
# city
# eventauthor
# eventdate
# eventdateend
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# telephone
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# eventauthor
# eventdate
# eventdateend
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# authorid
# city
# eventauthor
# eventdate
# eventdateend
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# telephone
# zip
# authorEvent
# authorid
# city
# eventauthor
# eventdate
# eventdateend
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# telephone
# zip
# authorEvent
# address1
# authorid
# city
# eventauthor
# eventdate
# eventdateend
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# telephone
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# eventauthor
# eventdate
# eventdateend
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# eventauthor
# eventdate
# eventdateend
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# eventauthor
# eventdate
# eventdateend
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# telephone
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# telephone
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# telephone
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# telephone
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# telephone
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# market
# state
# status
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# eventauthor
# eventdate
# eventdateend
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# telephone
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# eventauthor
# eventdate
# eventdateend
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# eventauthor
# eventdate
# eventdateend
# eventid
# eventtime
# ...
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# eventauthor
# eventdate
# eventdateend
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# telephone
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# telephone
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# telephone
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# telephone
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# telephone
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# telephone
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# telephone
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# telephone
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# telephone
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# eventauthor
# eventdate
# eventdateend
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventdateend
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# telephone
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# eventtime
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip
# authorEvent
# address1
# authorid
# city
# description
# eventauthor
# eventdate
# eventid
# isbn
# isbn10
# location
# market
# state
# status
# zip

# %%
event_source = []

for child in root:
    event_source.append(child.attrib)

# %%
event_participants = []

for child in root:
    
    try:
        author = child.find('eventauthor').text
        event_participants.append(author)
    except:
        event_participants.append('none')
        print("no author")
# Out:
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author

# %%
event_city = []

for child in root:
    
    try:
        city = child.find('city').text
        event_city.append(city)
    except:
        event_city.append('none')
        print("no city")
# Out:
# no city

# %%
event_date = []

for child in root:
    
    try:
        date = child.find('eventdate').text
        event_date.append(date)
    except:
        event_date.append('none')
        print("no date")

# %%
event_id = []

for child in root:
    
    try:
        ident = child.find('eventid').text
        event_id.append(ident)
    except:
        event_id.append('none')
        print("no id")

# %%
event_isbn = []

for child in root:
    
    try:
        isbn_numb = child.find('isbn').text
        event_isbn.append(isbn_numb)
    except:
        event_isbn.append('none')
        print("no isbn")

# %%
event_location = []

for child in root:
    
    try:
        location = child.find('location').text
        event_location.append(location)
    except:
        event_location.append('none')
        print("no loc")
# Out:
# no loc
# no loc
# no loc
# no loc
# no loc
# no loc
# no loc
# no loc
# no loc
# no loc
# no loc
# no loc
# no loc
# no loc
# no loc
# no loc
# no loc
# no loc
# no loc
# no loc
# no loc
# no loc
# no loc
# no loc
# no loc
# no loc
# no loc
# no loc
# no loc

# %%
event_market = []

for child in root:
    
    try:
        market = child.find('market').text
        event_market.append(market)
    except:
        event_market.append('none')
        print("no market")
# Out:
# no market

# %%
event_state = []

for child in root:
    
    try:
        state = child.find('state').text
        event_state.append(state)
    except:
        event_state.append('none')
        print("no state")

# %%
event_description = []

for child in root:
    
    try:
        description = child.find('description').text
        event_description.append(description)
    except:
        event_description.append('none')
        print("no description")
# Out:
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description

# %%
table_events = pd.DataFrame(event_id)
table_events = table_events.rename(columns={0:'event_id'})
table_events.head()
# Out:
#   event_id
# 0    86905
# 1   195684
# 2   777615
# 3   875780
# 4   954952

# %%
table_events['event_source']=event_source
table_events['event_isbn']=event_isbn
table_events['event_participants']=event_participants
table_events['event_date']=event_date
table_events['event_location']=event_location
table_events['event_city']=event_city
table_events['event_state']=event_state
table_events['event_description']=event_description
table_events['event_market']=event_market

# %%
table_events=table_events.replace('\r\n', '', regex=True)
table_events.head()
# Out:
#   event_id                                       event_source     event_isbn  \
# 0    86905  {'uri': 'https://reststop.randomhouse.com/reso...  9781400066469
# 1   195684  {'uri': 'https://reststop.randomhouse.com/reso...  9781599620886
# 2   777615  {'uri': 'https://reststop.randomhouse.com/reso...  9780385349246
# 3   875780  {'uri': 'https://reststop.randomhouse.com/reso...  9780449016169
# 4   954952  {'uri': 'https://reststop.randomhouse.com/reso...  9780451231529
#
#   event_participants  event_date  \
# 0    Arthur Phillips  04/22/2099
# 1   Marissa Guggiana  10/30/2020
# 2   Jillian Michaels  08/08/2104
# 3      James Nevison  12/03/2114
# 4       Kate Collins  10/16/2020
#
#                                       event_location           event_city  \
# 0                                  SPOKEN INTERLUDES            Irvington
# 1            The Feed BarnPoint Reyes Farmers Market  Point Reyes Station
# 2  International Fitness and Club Business Confer...              Toronto
# 3                       32 Books,3185 Edgemont Blvd.      North Vancouver
# 4                                               none         Merrillville
#
#   event_state                                  event_description  \
# 0          NY                                               none
# 1          CA  Butchering/cooking demo & booksigning with Mar...
# 2          ON                                               none
# 3          BC                                               none
# 4          IN                                         bookstore.
#
#             event_market
# 0  NY - New York Suburbs
# 1        CA - California
# 2  CAN - Toronto and GTA
# 3      CAN - BC Mainland
# 4      IN - Indianapolis

# %% [markdown]
# # Loading Data to Postgres

# %% [markdown]
# NYT DATA LOAD

# %%
#NYT DATA LOAD
# Dependent on the Goodreads/BooksDB section 

# Deal with password needed for sql conn
key = b'R_frnvbIOy25RMAXZtlk5yOn9x6m71YhQnfkpr2QM5w='
cipher_suite = Fernet(key)

with open('postgres.bin', 'rb') as file_object:
    for line in file_object:
        encryptedpwd = line
        
uncipher_text = (cipher_suite.decrypt(encryptedpwd))
pword = bytes(uncipher_text).decode("utf-8")

engine = create_engine('postgresql://postgres:' + pword + '@localhost:5432/ETL')
connection = engine.connect()
engine.table_names()

common_books = booksDB.merge(nyt_books,on=['book_id'])
common_books = common_books[['rank','weeks_on_list', 'book_id', 'publisher', 'book_review_link', 'category', 'current_as_of_date']]
common_books.index.name = 'reviews_id'


booksDB.to_sql(name='books', con=engine, if_exists='append', index=False)
common_books.to_sql(name='reviews', con=engine, if_exists='append', index=True)
