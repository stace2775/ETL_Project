# %% [markdown]
# # Dependecies

# %%
import numpy as np
import pandas as pd
import requests
import time
import json
from pprint import pprint
import xml.etree.ElementTree as ET
from collections import OrderedDict

# %%
import sqlalchemy
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func, inspect
from cryptography.fernet import Fernet

# %% [markdown]
# # NYT Data Extract/Transform

# %%
# API KEY 
ses_api_key = "EH3LYl2x8c4wLClt63RJZGBrZboUE507"

# Best Sellers Lists
nyt_lists_qry = "https://api.nytimes.com/svc/books/v3/lists/names.json?api-key=" + ses_api_key 
nyt_lists_results = requests.get(nyt_lists_qry).json()
nyt_lists_results
nyt_lists_df = pd.DataFrame(nyt_lists_results['results'])

# %%
nyt_lists_df.sort_values(['newest_published_date'], ascending = False)
# Out:
#                                  display_name  \
# 0             Combined Print & E-Book Fiction
# 11             Advice, How-To & Miscellaneous
# 1          Combined Print & E-Book Nonfiction
# 24                          Children’s Series
# 23                   Children’s Picture Books
# 20          Children’s Middle Grade Hardcover
# 27                      Young Adult Hardcover
# 6                        Paperback Nonfiction
# 2                           Hardcover Fiction
# 3                        Hardcover Nonfiction
# 4                     Paperback Trade Fiction
# 31                           Audio Nonfiction
# 53                         Sports and Fitness
# 52                                    Science
# 32                                   Business
# 30                              Audio Fiction
# 21          Children’s Middle Grade Paperback
# 8                           E-Book Nonfiction
# 28                      Young Adult Paperback
# 26                         Young Adult E-Book
# 7                              E-Book Fiction
# 5               Paperback Mass-Market Fiction
# 19             Children’s Middle Grade E-Book
# 14                                      Manga
# 13                    Paperback Graphic Books
# 12                    Hardcover Graphic Books
# 37                                  Espionage
# 51           Religion, Spirituality and Faith
# 50                      Race and Civil Rights
# 49              Politics and American History
# 48                      Parenthood and Family
# 46                     Love and Relationships
# 44                                      Humor
# 43                                     Health
# 41                       Games and Activities
# 40                              Food and Diet
# 39               Fashion, Manners and Customs
# 38                                Expeditions
# 54                                     Travel
# 35                                    Culture
# 34                       Crime and Punishment
# 33                                Celebrities
# 29                                    Animals
# 36                                  Education
# 45                       Indigenous Americans
# 25                                Young Adult
# 18                    Children’s Middle Grade
# 42                   Hardcover Business Books
# 47                   Paperback Business Books
# 15     Combined Hardcover & Paperback Fiction
# 16  Combined Hardcover & Paperback Nonfiction
# 10                   Paperback Advice & Misc.
# 9                    Hardcover Advice & Misc.
# 17                   Children’s Chapter Books
# 22                 Children’s Paperback Books
#
#                                list_name  \
# 0      Combined Print and E-Book Fiction
# 11       Advice How-To and Miscellaneous
# 1   Combined Print and E-Book Nonfiction
# 24                          Series Books
# 23                         Picture Books
# 20      Childrens Middle Grade Hardcover
# 27                 Young Adult Hardcover
# 6                   Paperback Nonfiction
# 2                      Hardcover Fiction
# 3                   Hardcover Nonfiction
# 4                Trade Fiction Paperback
# 31                      Audio Nonfiction
# 53                                Sports
# 52                               Science
# 32                        Business Books
# 30                         Audio Fiction
# 21      Childrens Middle Grade Paperback
# 8                      E-Book Nonfiction
# 28                 Young Adult Paperback
# 26                    Young Adult E-Book
# 7                         E-Book Fiction
# 5                  Mass Market Paperback
# 19         Childrens Middle Grade E-Book
# 14                                 Manga
# 1             2011-02-13   WEEKLY
# 24            2008-06-08   WEEKLY
# 23            2008-06-08   WEEKLY
# 20            2015-08-30   WEEKLY
# 27            2015-08-30   WEEKLY
# 6             2008-06-08   WEEKLY
# 2             2008-06-08   WEEKLY
# 3             2008-06-08   WEEKLY
# 4             2008-06-08   WEEKLY
# 31            2018-03-11  MONTHLY
# 53            2014-03-02  MONTHLY
# 52            2013-04-14  MONTHLY
# 32            2013-11-03  MONTHLY
# 30            2018-03-11  MONTHLY
# 21            2015-08-30   WEEKLY
# 8             2011-02-13   WEEKLY
# 28            2015-08-30   WEEKLY
# 26            2015-08-30   WEEKLY
# 7             2011-02-13   WEEKLY
# 5             2008-06-08   WEEKLY
# 19            2015-08-30   WEEKLY
# 14            2009-03-15   WEEKLY
# 13            2009-03-15   WEEKLY
# 12            2009-03-15   WEEKLY
# 37            2014-12-14  MONTHLY
# 51            2014-09-07  MONTHLY
# 50            2014-12-14  MONTHLY
# 49            2011-07-03  MONTHLY
# 48            2014-09-07  MONTHLY
# 46            2014-09-07  MONTHLY
# 44            2014-09-07  MONTHLY
# 43            2014-10-12  MONTHLY
# 41            2014-10-12  MONTHLY
# 40            2013-09-01  MONTHLY
# 39            2014-10-12  MONTHLY
# 38            2014-12-14  MONTHLY
# 54            2014-09-07  MONTHLY
# 35            2014-10-12  MONTHLY
# 34            2014-10-12  MONTHLY
# 33            2014-09-07  MONTHLY
# 29            2014-09-07  MONTHLY
# 36            2014-10-12  MONTHLY
# 45            2014-12-14  MONTHLY
# 25            2012-12-16   WEEKLY
# 18            2012-12-16   WEEKLY
# 42            2011-07-03  MONTHLY
# 47            2011-07-03  MONTHLY
# 15            2011-02-13   WEEKLY
# 16            2011-02-13   WEEKLY
# 10            2008-06-08   WEEKLY
# 9             2008-06-08   WEEKLY
# 17            2008-06-08   WEEKLY
# 22            2008-06-08   WEEKLY

# %%
# Hardcover NONFiction Best Sellers Extract
nyt_h_nfiction_qry = "https://api.nytimes.com/svc/books/v3/lists/current/hardcover-nonfiction.json?api-key=" + ses_api_key 
nyt_h_nfiction_results = requests.get(nyt_h_nfiction_qry).json()
nyt_h_nfiction_results
nyt_h_nfiction = nyt_h_nfiction_results['results']['books']

# %%
# Hardcover NONFiction Transform
nyt_h_nf_df = pd.DataFrame(nyt_h_nfiction)
nyt_h_nf_df = nyt_h_nf_df[['rank','weeks_on_list', 'primary_isbn13', 'publisher', 'book_review_link']]
nyt_h_nf_df = nyt_h_nf_df.rename(columns={'primary_isbn13':'book_id'})
nyt_h_nf_df['book_id']=nyt_h_nf_df['book_id'].astype(np.int64)



category = 'Hardcover Non-Fiction'
nyt_h_nf_df['category'] = category
date = pd.datetime.now()
nyt_h_nf_df['current_as_of_date'] = date

nyt_h_nf_df.head()
# Out:
#    rank  weeks_on_list        book_id         publisher  \
# 0     1             78  9780399590504      Random House
# 1     2              1  9780525509288         One World
# 2     3             40  9781524763138             Crown
# 3     4              6  9781451642292       Avid Reader
# 4     5             15  9781501168680  Simon & Schuster
#
#                                     book_review_link               category  \
# 0  https://www.nytimes.com/2018/03/01/books/revie...  Hardcover Non-Fiction
# 1                                                     Hardcover Non-Fiction
# 2  https://www.nytimes.com/2018/12/06/books/revie...  Hardcover Non-Fiction
# 3  https://www.nytimes.com/2019/06/28/books/revie...  Hardcover Non-Fiction
# 4  https://www.nytimes.com/2019/05/13/books/revie...  Hardcover Non-Fiction
#
#           current_as_of_date
# 0 2019-08-24 11:12:47.897538
# 1 2019-08-24 11:12:47.897538
# 2 2019-08-24 11:12:47.897538
# 3 2019-08-24 11:12:47.897538
# 4 2019-08-24 11:12:47.897538

# %%
# Paperback NONFiction Best Sellers
nyt_p_nfiction_qry = "https://api.nytimes.com/svc/books/v3/lists/current/paperback-nonfiction.json?api-key=" + ses_api_key 
nyt_p_nfiction_results = requests.get(nyt_p_nfiction_qry).json()
nyt_p_nfiction_results
nyt_p_nfiction = nyt_p_nfiction_results['results']['books']

# %%
# Paperback NONFiction Transform
nyt_p_nf_df = pd.DataFrame(nyt_p_nfiction)
nyt_p_nf_df = nyt_p_nf_df[['rank','weeks_on_list', 'primary_isbn13', 'publisher', 'book_review_link']]
nyt_p_nf_df = nyt_p_nf_df.rename(columns={'primary_isbn13':'book_id'})
nyt_p_nf_df['book_id']=nyt_p_nf_df['book_id'].astype(np.int64)

category = 'Paperback Non-Fiction'
nyt_p_nf_df['category'] = category
date = pd.datetime.now()
nyt_p_nf_df['current_as_of_date'] = date

nyt_p_nf_df.head()
# Out:
#    rank  weeks_on_list        book_id         publisher book_review_link  \
# 0     1             27  9780399588198    Spiegel & Grau
# 1     2             66  9780062316110  Harper Perennial
# 2     3             58  9780807047415      Beacon Press
# 3     4            166  9780812984965    Spiegel & Grau
# 4     5             43  9780143127741           Penguin
#
#                 category         current_as_of_date
# 0  Paperback Non-Fiction 2019-08-24 11:12:51.371927
# 1  Paperback Non-Fiction 2019-08-24 11:12:51.371927
# 2  Paperback Non-Fiction 2019-08-24 11:12:51.371927
# 3  Paperback Non-Fiction 2019-08-24 11:12:51.371927
# 4  Paperback Non-Fiction 2019-08-24 11:12:51.371927

# %%
# Hardcover Fiction Best Sellers
nyt_h_fiction_qry = "https://api.nytimes.com/svc/books/v3/lists/current/hardcover-fiction.json?api-key=" + ses_api_key 
nyt_h_fiction_results = requests.get(nyt_h_fiction_qry).json()
nyt_h_fiction_results
nyt_h_fiction = nyt_h_fiction_results['results']['books']

# %%
# Hardcover Fiction Transform
nyt_h_f_df = pd.DataFrame(nyt_h_fiction)
nyt_h_f_df = nyt_h_f_df[['rank','weeks_on_list', 'primary_isbn13', 'publisher', 'book_review_link']]
nyt_h_f_df = nyt_h_f_df.rename(columns={'primary_isbn13':'book_id'})
nyt_h_f_df['book_id']=nyt_h_f_df['book_id'].astype(np.int64)

category = 'Hardcover Fiction'
nyt_h_f_df['category'] = category
date = pd.datetime.now()
nyt_h_f_df['current_as_of_date'] = date

nyt_h_f_df.head()
# Out:
#    rank  weeks_on_list        book_id      publisher  \
# 0     1             50  9780735219090         Putnam
# 1     2              2  9780316527583  Little, Brown
# 2     3              1  9781250051059       Minotaur
# 3     4              4  9781538750568  Grand Central
# 4     5              5  9780385537070      Doubleday
#
#                                     book_review_link           category  \
# 0                                                     Hardcover Fiction
# 1                                                     Hardcover Fiction
# 2                                                     Hardcover Fiction
# 3                                                     Hardcover Fiction
# 4  https://www.nytimes.com/2019/07/11/books/revie...  Hardcover Fiction
#
#           current_as_of_date
# 0 2019-08-24 11:13:03.738965
# 1 2019-08-24 11:13:03.738965
# 2 2019-08-24 11:13:03.738965
# 3 2019-08-24 11:13:03.738965
# 4 2019-08-24 11:13:03.738965

# %%
# Trade Fiction Paperback Best Sellers
nyt_tfp_qry = "https://api.nytimes.com/svc/books/v3/lists/current/trade-fiction-paperback.json?api-key=" + ses_api_key 
nyt_tfp_results = requests.get(nyt_tfp_qry).json()
nyt_tfp_results
nyt_tfp = nyt_tfp_results['results']['books']

# %%
# Trade Fiction Paperback Transform
nyt_tfp_df = pd.DataFrame(nyt_tfp)
nyt_tfp_df = nyt_tfp_df[['rank','weeks_on_list', 'primary_isbn13', 'publisher', 'book_review_link']]
nyt_tfp_df = nyt_tfp_df.rename(columns={'primary_isbn13':'book_id'})
nyt_tfp_df['book_id']=nyt_tfp_df['book_id'].astype(np.int64)

category = 'Trade Fiction Paperback'
nyt_tfp_df['category'] = category
date = pd.datetime.now()
nyt_tfp_df['current_as_of_date'] = date

nyt_tfp_df.head()
# Out:
#    rank  weeks_on_list        book_id         publisher  \
# 0     1            164  9780062364913  Harper Perennial
# 1     2             50  9780062797155            Harper
# 2     3             15  9780735224315           Penguin
# 3     4              2  9781400033416           Vintage
# 4     5             13  9780425284704        Ballantine
#
#                                     book_review_link                 category  \
# 0                                                     Trade Fiction Paperback
# 1  https://www.nytimes.com/2018/11/16/books/revie...  Trade Fiction Paperback
# 2  https://www.nytimes.com/2017/09/25/books/revie...  Trade Fiction Paperback
# 3  https://www.nytimes.com/1987/09/02/books/books...  Trade Fiction Paperback
# 4                                                     Trade Fiction Paperback
#
#           current_as_of_date
# 0 2019-08-24 11:13:05.808528
# 1 2019-08-24 11:13:05.808528
# 2 2019-08-24 11:13:05.808528
# 3 2019-08-24 11:13:05.808528
# 4 2019-08-24 11:13:05.808528

# %%
# YA Hardcover Best Sellers
nyt_ya_qry = "https://api.nytimes.com/svc/books/v3/lists/current/young-adult-hardcover.json?api-key=" + ses_api_key 
nyt_ya_results = requests.get(nyt_ya_qry).json()
nyt_ya_results
nyt_ya = nyt_ya_results['results']['books']

# %%
# YA Hardcover Transform
nyt_ya_df = pd.DataFrame(nyt_ya)
nyt_ya_df = nyt_ya_df[['rank','weeks_on_list', 'primary_isbn13', 'publisher', 'book_review_link']]
nyt_ya_df = nyt_ya_df.rename(columns={'primary_isbn13':'book_id'})
nyt_ya_df['book_id']=nyt_ya_df['book_id'].astype(np.int64)

category = 'YA Hardcover'
nyt_ya_df['category'] = category
date = pd.datetime.now()
nyt_ya_df['current_as_of_date'] = date

nyt_ya_df.head()
# Out:
#    rank  weeks_on_list        book_id         publisher book_review_link  \
# 0     1            129  9780062498533     Balzer + Bray
# 1     2             37  9781534451568  Simon & Schuster
# 2     3             17  9780062662804        HarperTeen
# 3     4             76  9781250170972              Holt
# 4     5             87  9781524714680         Delacorte
#
#        category         current_as_of_date
# 0  YA Hardcover 2019-08-24 11:13:08.240645
# 1  YA Hardcover 2019-08-24 11:13:08.240645
# 2  YA Hardcover 2019-08-24 11:13:08.240645
# 3  YA Hardcover 2019-08-24 11:13:08.240645
# 4  YA Hardcover 2019-08-24 11:13:08.240645

# %%
nyt_books = pd.concat([nyt_h_nf_df, nyt_p_nf_df, nyt_h_f_df, nyt_tfp_df, nyt_ya_df]).reset_index()
del nyt_books['index']
nyt_books.index.name = 'reviews_id'
nyt_books.head()
# Out:
#             rank  weeks_on_list        book_id         publisher  \
# reviews_id
# 0              1             78  9780399590504      Random House
# 1              2              1  9780525509288         One World
# 2              3             40  9781524763138             Crown
# 3              4              6  9781451642292       Avid Reader
# 4              5             15  9781501168680  Simon & Schuster
#
#                                              book_review_link  \
# reviews_id
# 0           https://www.nytimes.com/2018/03/01/books/revie...
# 1
# 2           https://www.nytimes.com/2018/12/06/books/revie...
# 3           https://www.nytimes.com/2019/06/28/books/revie...
# 4           https://www.nytimes.com/2019/05/13/books/revie...
#
#                          category         current_as_of_date
# reviews_id
# 0           Hardcover Non-Fiction 2019-08-24 11:12:47.897538
# 1           Hardcover Non-Fiction 2019-08-24 11:12:47.897538
# 2           Hardcover Non-Fiction 2019-08-24 11:12:47.897538
# 3           Hardcover Non-Fiction 2019-08-24 11:12:47.897538
# 4           Hardcover Non-Fiction 2019-08-24 11:12:47.897538

# %% [markdown]
# # ISBN DB Data Extract/Transform

# %%
# Checking to see if a Publisher exists, and if so, all the available imprints
h = {'Authorization': '43372_e0f4fd14cd8558f5683ec63878bf6ad5'}
publisher = requests.get("https://api2.isbndb.com/publishers/Random%20House", headers=h)
publisher_results = publisher.json()
publisher_results
# Out:
# {'total': 6820,
#  'publishers': ['Random House-',
#   'Random House ;',
#   'Random-house',
#   'Random House School Division, Random House',
#   'Sudamericana / Random House',
#   'Random House (merchandising)',
#   'Anchor / Random House',
#   'Debate / Random House',
#   'Random House, 1998',
#   'Dell / Random House',
#   'Random House / Disney',
#   'Vintage (random House)',
#   'Doubleday Random House',
#   'Quillmark, Random House',
#   'Random House: Vintage',
#   'Random House / Salamander',
#   'Random House, 2003',
#   'Random House @ Trade',
#   'Pimlico (random House)',
#   'Random House N.z']}

# %%
# Pulling books by Publisher name
book_results_1 = requests.get("https://api2.isbndb.com/books/Random%20House?", headers=h, params={'page':1, 'pageSize':1000, 'beta':0}).json()
book_results_2 = requests.get("https://api2.isbndb.com/books/Random%20House?", headers=h, params={'page':2, 'pageSize':1000, 'beta':0}).json()
book_results_3 = requests.get("https://api2.isbndb.com/books/Random%20House?", headers=h, params={'page':3, 'pageSize':1000, 'beta':0}).json()
book_results_4 = requests.get("https://api2.isbndb.com/books/Penguin?", headers=h, params={'page':1, 'pageSize':1000, 'beta':0}).json()
book_results_5 = requests.get("https://api2.isbndb.com/books/Penguin?", headers=h, params={'page':2, 'pageSize':1000, 'beta':0}).json()
book_results_6 = requests.get("https://api2.isbndb.com/books/Penguin?", headers=h, params={'page':3, 'pageSize':1000, 'beta':0}).json()
book_results_7 = requests.get("https://api2.isbndb.com/books/Simon%20&%20Schuster?", headers=h, params={'page':1, 'pageSize':1000, 'beta':0}).json()
book_results_8 = requests.get("https://api2.isbndb.com/books/Simon%20&%20Schuster?", headers=h, params={'page':2, 'pageSize':1000, 'beta':0}).json()
book_results_9 = requests.get("https://api2.isbndb.com/books/Simon%20&%20Schuster?", headers=h, params={'page':3, 'pageSize':1000, 'beta':0}).json()
book_results_10 = requests.get("https://api2.isbndb.com/books/Knopf?", headers=h, params={'page':1, 'pageSize':1000, 'beta':0}).json()

# %%
# Putting the results into dataframes
b1_df = pd.DataFrame(book_results_1['books'])
b2_df = pd.DataFrame(book_results_2['books'])
b3_df = pd.DataFrame(book_results_3['books'])
b4_df = pd.DataFrame(book_results_4['books'])
b5_df = pd.DataFrame(book_results_5['books'])
b6_df = pd.DataFrame(book_results_6['books'])
b7_df = pd.DataFrame(book_results_7['books'])
b8_df = pd.DataFrame(book_results_8['books'])
b9_df = pd.DataFrame(book_results_9['books'])
b10_df = pd.DataFrame(book_results_10['books'])

book_data = pd.concat([b1_df, b2_df, b3_df, b4_df, b5_df, b6_df, b7_df, b8_df, b9_df, b10_df])
book_data.head()
# Out:
#                                              authors    binding  \
# 0  [Miller, Frederic P., Vandome, Agnes F., McBre...        NaN
# 1                                   [Stanley Newman]  Paperback
# 2                                          [Unknown]  Paperback
# 3                                                NaN        NaN
# 4                                   [Stanley Newman]  Paperback
#
#   date_published edition                                              image  \
# 0           2010     NaN  https://images.isbndb.com/covers/85/23/9786131...
# 1           2007     NaN  https://images.isbndb.com/covers/62/61/9780812...
# 2           1994     NaN  https://images.isbndb.com/covers/98/79/9780345...
# 3            NaN     NaN  https://images.isbndb.com/covers/37/06/9780679...
# 4           2007     NaN  https://images.isbndb.com/covers/62/78/9780812...
#
#          isbn         isbn13   msrp publish_date  \
# 0  6131748527  9786131748523    NaN         2010
# 1  0812936264  9780812936261   6.95         2007
# 2  0345389875  9780345389879  71.84         1994
# 3  0679733701  9780679733706    NaN          NaN
# 4  0812936272  9780812936278   6.95         2007
#
#                       publisher subjects  \
# 0                           NaN      NaN
# 1  Random House Puzzles & Games      NaN
# 2              Ballantine Books      NaN
# 3                           NaN      NaN
# 4  Random House Puzzles & Games      NaN
#
#                                             synopsys  \
# 0                                                NaN
# 1  <p><p>whether You&#8217;ve Spent Your Day Weed...
# 2                                                NaN
# 3                                                NaN
# 4  <p><p>what Better Way To Cool Down After A Hot...
#
#                                                title  \
# 0                                       Random House
# 1  Random House Springtime Crosswords (random Hou...
# 2  Random House Webster's Dictionary Random House...
# 3  Random House Dictionary/random House Rogets Th...
# 4  Random House Summer Nights Crosswords (random ...
#
#                                           title_long
# 0                                       Random-house
# 1  Random House Springtime Crosswords (random Hou...
# 2  Random House Webster's Dictionary Random House...
# 3  Random_house_dictionary-random_house_rogets_th...
# 4  Random House Summer Nights Crosswords (random ...

# %%
# Dealing with nulls and dtypes
book_data.dropna(axis=0, subset=['isbn13'])
book_data['isbn13']=book_data['isbn13'].astype(float)

# %%
# Sending it to csv
book_data.to_csv('book_data.csv')

# %% [markdown]
# # Goodreads Data Extract/Transform

# %%
# Import CSV

books_csv = "book_data_clean.csv"
booksdata = pd.read_csv(books_csv)
booksdata.dtypes
# Out:
# authors     object
# isbn13     float64
# title       object
# dtype: object

# %%
# Clean database (booksID from isbn13, title, authors)

booksDB = booksdata[["isbn13", "title", "authors"]]
booksDB = booksDB.rename(columns={"isbn13": "book_id",
                                    "title": "title",
                                    "authors": "authors"})

booksDB['book_id'] = booksDB['book_id'].drop_duplicates()
booksDB = booksDB.dropna()
booksDB['book_id'] = booksDB['book_id'].astype(np.int64)
booksDB
# Out:
#             book_id                                              title  \
# 0     9786131748523                                       Random House
# 1     9780812936261  Random House Springtime Crosswords (random Hou...
# 3     9780345389879  Random House Webster's Dictionary Random House...
# 4     9780812936278  Random House Summer Nights Crosswords (random ...
# 5     9780812936285  Random House Harvest Moon Crosswords (random H...
# 6     9780394534428                            Random House Dictionary
# 7     9780812927658                             Random House Lexercise
# 8     9780070136427                              Random House Handbook
# 9     9780812934991                            Random House Crosswords
# 10    9780812934151                            Random House Crosswords
# 11    9780375425875                              Random House treasury
# 12    9780394845982                             Random House Dollhouse
# 13    9780812935004                            Random House Crosswords
# 14    9780345377784                             Random House Thesaurus
# 15    9780079112521                              Random House Handbook
# 16    9786134693240                                 Random House Tower
# 17    9780812933901                              Random House Crostics
# 18    9780812936735  Random House Casual Crosswords, Volume 4 (rand...
# 19    9780812936667  Random House Casual Crosswords, Volume 3 (rand...
# 20    9780375723315  Random House Casual Crosswords, Volume 7 (rand...
# 21    9780375723322  Random House Casual Crosswords, Volume 8 (rand...
# 22    9780679750246  The Random House Book Of Vegetables (random Ho...
# 23    9780679415701  Random House Geographical Dictionary (random H...
# 24    9780394542102  The Random House College Dictionary and the Ra...
# 25    9780375722318  Random House Webster's Large Print Grammar & U...
# 26    9780613057561  Random House Book Of Horses And Horsemanship (...
# 28    9780394027258  The Random House English Handbook, (the Random...
# 29    9780679415800  Random House Biographical Dictionary (random H...
# 30    9780739325971               The House (random House Large Print)
# 31    9780345322982                        The Random House Dictionary
# ...             ...                                                ...
# 9281  9783897657328  Jim Knopf Und Lukas Der Lokomotivführer 1: Von...
# 9282  9780394712727  Glass Tableware, Bowls, & Vases (the Knopf Col...
# 9283  9780394582931  Barbecued Ribs, Smoked Butts, And Other Great ...
# 9284  9780394890272  The Country Mouse And The City Mouse (knopf Nu...
# 9285  9780394714936  Folk Art: Painting, Sculpture (the Knopf Colle...
# 9286  9783522436021  Jim Knopf Und Lukas Der Lokomotivführer Machen...
# 9287  9783522435567  Jim Knopf Und Lukas Der Lokomotivführer Gehen ...
# 9288  9780979583056  Knoop And Knopf In Missouri And Parts Of Iowa,...
# 9289  9780394498928  Sixty Photographs: To Celebrate The Sixtieth A...
# 9291                                ['Alfred A. Knopf']
# 9292                                   ['Jeanne Voltz']
# 9293                                        ['Ende M.']
# 9294                             ['Marvin D. Schwartz']
# 9295                                   ['Janie Hibler']
# 9297                                ['Cathy Henderson']
# 9298                      ['Serge Prokofiev', 'Loriot']
# 9299                           ['Jane Shadel Spillman']
# 9300                                   ['Isaac Asimov']
# 9301  ['Laessoe Thomas And Anna Del Conte And Gary L...
# 9302                                  ['Bruce Aidells']
# 9303                               ['Nancy Verde Barr']
# 9304  ['Floyd Abrams', 'Robert H Bork', 'Additional ...
# 9305                   ['Bruce Aidells', 'Denis Kelly']
# 9306                          ['Wilhelm Von Ploennies']
# 9307                               ['Nancy Verde Barr']
# 9309                              ['Amy Root Clements']
# 9310                               ['Morris Ebenstein']
# 9311                                        ['--n/a--']
# 9312                           ['Wilhelm Von Plönnies']
#
# [8734 rows x 3 columns]

# %% [markdown]
# # Penguin Events Data Extract/Transform

# %%
#Utilizing Penguin Randomhouse API to access event information
#API will only return an XML-formatted result
url = 'https://reststop.randomhouse.com/resources/authorevents/?start=0&max=0&expandLevel=1'

response = requests.get(url)

root = ET.fromstring(response.content)

# %%
#finding the child tags of the XML tree
for child in root.iter('*'):
    print(child.tag)
    break
# Out:
# authorevents

# %%
#Creating empty list, then appending event source info

event_list = []

for child in root:
    event_list.append(child.attrib)

# %%
#Returned a list of dictionaries, so created a list to just
#extract the values from each dictionary in the list

event_source = []
for i in event_list:
    event_source.append(i['uri'])

# %%
#Creating empty list, then appending event participant info
#To make sure each list is the same length, 'none' will go into 
#anything that is not found

event_participants = []

for child in root:
    
    try:
        author = child.find('eventauthor').text
        event_participants.append(author)
    except:
        event_participants.append('none')
        print("no author")
# Out:
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author
# no author

# %%
#Creating empty list, then appending event participant info
#To make sure each list is the same length, 'none' will go into 
#anything that is not found

event_city = []

for child in root:
    
    try:
        city = child.find('city').text
        event_city.append(city)
    except:
        event_city.append('none')
        print("no city")
# Out:
# no city

# %%
#Creating empty list, then appending event date info
#To make sure each list is the same length, 'none' will go into 
#anything that is not found

event_date = []

for child in root:
    
    try:
        date = child.find('eventdate').text
        event_date.append(date)
    except:
        event_date.append('none')
        print("no date")

# %%
#Creating empty list, then appending event id info
#To make sure each list is the same length, 'none' will go into 
#anything that is not found

event_id = []

for child in root:
    
    try:
        ident = child.find('eventid').text
        event_id.append(ident)
    except:
        event_id.append('none')
        print("no id")

# %%
#Creating empty list, then appending event isbn info
#To make sure each list is the same length, 'none' will go into 
#anything that is not found

event_isbn = []

for child in root:
    
    try:
        isbn_numb = child.find('isbn').text
        event_isbn.append(isbn_numb)
    except:
        event_isbn.append('none')
        print("no isbn")

# %%
#Creating empty list, then appending event location info
#To make sure each list is the same length, 'none' will go into 
#anything that is not found

event_location = []

for child in root:
    
    try:
        location = child.find('location').text
        event_location.append(location)
    except:
        event_location.append('none')
        print("no loc")
# Out:
# no loc
# no loc
# no loc
# no loc
# no loc
# no loc
# no loc
# no loc
# no loc
# no loc
# no loc
# no loc
# no loc
# no loc
# no loc
# no loc
# no loc
# no loc
# no loc
# no loc
# no loc
# no loc
# no loc
# no loc
# no loc
# no loc
# no loc
# no loc
# no loc

# %%
#Creating empty list, then appending event market info
#To make sure each list is the same length, 'none' will go into 
#anything that is not found

event_market = []

for child in root:
    
    try:
        market = child.find('market').text
        event_market.append(market)
    except:
        event_market.append('none')
        print("no market")
# Out:
# no market

# %%
#Creating empty list, then appending event state info
#To make sure each list is the same length, 'none' will go into 
#anything that is not found

event_state = []

for child in root:
    
    try:
        state = child.find('state').text
        event_state.append(state)
    except:
        event_state.append('none')
        print("no state")

# %%
#Creating empty list, then appending event description info
#To make sure each list is the same length, 'none' will go into 
#anything that is not found

event_description = []

for child in root:
    
    try:
        description = child.find('description').text
        event_description.append(description)
    except:
        event_description.append('none')
        print("no description")
# Out:
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description
# no description

# %%
#Creating initial dataframe
table_events = pd.DataFrame(event_id)
table_events = table_events.rename(columns={0:'event_id'})
table_events.head()
# Out:
#   event_id
# 0    86905
# 1   195684
# 2   777615
# 3   875780
# 4   954952

# %%
#Appending each column to table_events dataframe
table_events['event_source']=event_source
table_events['book_id']=event_isbn
table_events['event_participants']=event_participants
table_events['event_date']=event_date
table_events['event_location']=event_location
table_events['event_city']=event_city
table_events['event_state']=event_state
table_events['event_description']=event_description
table_events['event_market']=event_market

# %%
#Transforming columns to clean of characters and change data type
table_events['event_location']=table_events['event_location'].replace('\r\n','', regex=True)
table_events['event_source']=table_events['event_source'].replace('{','', regex=True)
table_events['book_id']=table_events['book_id'].astype(int)
table_events.set_index(['event_id'])
# Out:
#                                                event_source        book_id  \
# event_id
# 86905     https://reststop.randomhouse.com/resources/aut...  9781400066469
# 195684    https://reststop.randomhouse.com/resources/aut...  9781599620886
# 777615    https://reststop.randomhouse.com/resources/aut...  9780385349246
# 875780    https://reststop.randomhouse.com/resources/aut...  9780449016169
# 954952    https://reststop.randomhouse.com/resources/aut...  9780451231529
# 1019979   https://reststop.randomhouse.com/resources/aut...  9781592408177
# 9065648   https://reststop.randomhouse.com/resources/aut...  9780525579083
# 9741557   https://reststop.randomhouse.com/resources/aut...  9781496713193
# 9718950   https://reststop.randomhouse.com/resources/aut...  9780771009433
# 9729136   https://reststop.randomhouse.com/resources/aut...  9780307959409
# 9729751   https://reststop.randomhouse.com/resources/aut...  9780786041800
# 9718919   https://reststop.randomhouse.com/resources/aut...  9780771009433
# 9718937   https://reststop.randomhouse.com/resources/aut...  9780771009433
# 9718957   https://reststop.randomhouse.com/resources/aut...  9780771009433
# 9718975   https://reststop.randomhouse.com/resources/aut...  9780771009433
# 9718994   https://reststop.randomhouse.com/resources/aut...  9780771009433
# 9719151   https://reststop.randomhouse.com/resources/aut...  9781496723475
# 9729717   https://reststop.randomhouse.com/resources/aut...  9781580897969
# 9729728   https://reststop.randomhouse.com/resources/aut...  9781496717252
# 9751684   https://reststop.randomhouse.com/resources/aut...  9780525522508
# 9751736   https://reststop.randomhouse.com/resources/aut...  9780525522508
# 9751743   https://reststop.randomhouse.com/resources/aut...  9780525522508
# 9751747   https://reststop.randomhouse.com/resources/aut...  9780525522508
# 9751754   https://reststop.randomhouse.com/resources/aut...  9780525522508
# 9718958   https://reststop.randomhouse.com/resources/aut...  9780771009433
# 9718982   https://reststop.randomhouse.com/resources/aut...  9780771009433
# 9718990   https://reststop.randomhouse.com/resources/aut...  9780771009433
# 10984370            CAMBRIDGE          MA
# 10948809              RALEIGH          NC
# 10948809              RALEIGH          NC
# 10948814           DOYLESTOWN          PA
# 10948814           DOYLESTOWN          PA
# 10948815         CORAL GABLES          FL
# 10948815         CORAL GABLES          FL
# 10948816           BOCA RATON          FL
# 10948816           BOCA RATON          FL
# 10948817              DECATUR          GA
# 10948817              DECATUR          GA
# 10948820                MIAMI          FL
# 10948820                MIAMI          FL
# 10948827             TRIANGLE          VA
# 10948876            SAN BRUNO          CA
# 10984808             Pasadena          CA
# 10948880               DENVER          CO
# 10948881            IOWA CITY          IA
# 10948882              DUBUQUE          IA
# 10948886       WEST HOLLYWOOD          CA
# 10959413          ALBUQUERQUE          NM
# 10959465             New York          NY
# 10998064           Woodbridge          CT
# 10985136         Philadelphia          PA
# 10998089           Harrisburg          PA
# 10970825              DECATUR          GA
# 10970825              DECATUR          GA
# 10985961              Toronto          ON
# 10948643              Chicago          IL
#
#                                           event_description  \
# event_id
# 86905                                                  none
# 195684    Butchering/cooking demo & booksigning with Mar...
# 777615                                                 none
# 875780                                                 none
# 954952                                           bookstore.
# 1019979                                       author event.
# 9065648                               Panels, Signings, Q&A
# 9741557                            Cincinnati Book Festival
# 9718950                     Margaret Atwood In Conversation
# 9729136                                                none
# 9729751         Joint Event: REAVIS WORTHAM & JOHN GILSTRAP
# 9718919         Reading and discussion with Margaret Atwood
# 9718937   Indigo hosts In Conversation with Margaret Atwood
# 9718957                     Margaret Atwood In Conversation
# 9718975                     Margaret Atwood In Conversation
# 9718994                     Margaret Atwood In Conversation
# 9719151                                  Book Party/Signing
# 9729717   Featured author at story times and panel discu...
# 9729728                                  Multi-Author Event
# 9751684                                  Talk, Q&A, Signing
# 9751736                                  Talk, Q&A, Signing
# 9751743                                  Talk, Q&A, Signing
# 9751747                                  Talk, Q&A, Signing
# 9751754                                  Talk, Q&A, Signing
# 9718958                     Margaret Atwood In Conversation
# 9718982                     Margaret Atwood In Conversation
# 9718990                     Margaret Atwood In Conversation
# 9718992       National Civic Saturday event with book table
# 1834206                                                none
# 1834206                                                none
# ...                                                     ...
# 10984348            Osipov will give a talk on September 25
# 10984370                      Maxim Osipov will give a talk
# 10948809                                Chris in attendance
# 10948809                                Chris in attendance
# 10948814                           In-store event with Brad
# 10948814                           In-store event with Brad
# 10948815  Read to Learn Books - daytime reading circle e...
# 10948815  Read to Learn Books - daytime reading circle e...
# 10948816                   Evening in-store event with Brad
# 10948816                   Evening in-store event with Brad
# 10948817                           Daytime event with Chris
# 10948817                           Daytime event with Chris
# 10948820                           Daytime event with Chris
# 10948820                           Daytime event with Chris
# 10948827                                       Talk and Q&A
# 10948876                                 With Kathryn Berla
# 10984808                                               none
# 10948880                                               none
# 10948881                                               none
# 10948882                                               none
# 10948886                With Amy Spalding and Abdi Nazemian
# 10959413                                               none
# 10959465                 Not Your Mother's Tinkerbell Panel
# 10998064    Friends of the Library Purves Lecture & Signing
# 10985136                                              event
# 10998089                                        Author Talk
# 10970825                                               none
# 10970825                                               none
# 10985961       In conversation with Nahlah Ayed for "Ideas"
# 10948643                                      Chicago event
#
#                         event_market
# event_id
# 86905          NY - New York Suburbs
# 195684               CA - California
# 777615         CAN - Toronto and GTA
# 875780             CAN - BC Mainland
# 954952             IN - Indianapolis
# 1019979                  MA - Boston
# 9065648                  MA - Boston
# 9741557              OH - Cincinnati
# 9718950            CAN - BC Mainland
# 9729136               TN - Nashville
# 9729751                   TX - Texas
# 9718919            CAN - Ont Eastern
# 9718937        CAN - Toronto and GTA
# 9718957          CAN - BC/Vcr Island
# 9718975                    CAN - Man
# 9718994                 CAN - Quebec
# 9719151              PA - Pittsburgh
# 9729717                OR - Portland
# 9729728            PA - Pennsylvania
# 9751684            PA - Philadelphia
# 9751736          NC - Raleigh/Durham
# 9751743                OR - Portland
# 9751747          NC - Raleigh/Durham
# 9751754                 WY - Wyoming
# 9718958                   CAN - Alta
# 9718982               CAN - Atlantic
# 9718990               CAN - Atlantic
# 9718992           OK - Oklahoma City
# 1834206            CAN - Ont Eastern
# 1834206            CAN - Ont Eastern
# ...                              ...
# 10984348                 NY - Albany
# 10984370                 MA - Boston
# 10948809         NC - Raleigh/Durham
# 10948809         NC - Raleigh/Durham
# 10948814           PA - Pennsylvania
# 10948814           PA - Pennsylvania
# 10948815                FL - Florida
# 10948815                FL - Florida
# 10948816                FL - Florida
# 10948816                FL - Florida
# 10948817                GA - Georgia
# 10948817                GA - Georgia
# 10948820  FL - Miami/Fort Lauderdale
# 10948820  FL - Miami/Fort Lauderdale
# 10948827               VA - Virginia
# 10948876             CA - California
# 10984808            CA - Los Angeles
# 10948880                 CO - Denver
# 10948881              IA - Iowa City
# 10948882                   IA - Iowa
# 10948886            CA - Los Angeles
# 10959413   NM - Albuquerque/Santa Fe
# 10959465               NY - New York
# 10998064            CT - Connecticut
# 10985136           PA - Philadelphia
# 10998089             PA - Harrisburg
# 10970825                GA - Atlanta
# 10970825                GA - Atlanta
# 10985961       CAN - Toronto and GTA
# 10948643                IL - Chicago
#
# [1775 rows x 9 columns]

# %%
#merging events to match books
merged_events = table_events.merge(booksDB, how='inner', on='book_id')
merged_events
# Out:
#    event_id                                       event_source        book_id  \
# 0  10476151  https://reststop.randomhouse.com/resources/aut...  9780241299838
# 1  10476160  https://reststop.randomhouse.com/resources/aut...  9780241299838
# 2  10476134  https://reststop.randomhouse.com/resources/aut...  9780241299838
# 3  10476140  https://reststop.randomhouse.com/resources/aut...  9780241299838
# 4  10476145  https://reststop.randomhouse.com/resources/aut...  9780241299838
#
#   event_participants  event_date  \
# 0      Jhumpa Lahiri  11/07/2019
# 1      Jhumpa Lahiri  10/02/2019
# 2      Jhumpa Lahiri  09/13/2019
# 3      Jhumpa Lahiri  09/12/2019
# 4      Jhumpa Lahiri  10/10/2019
#
#                                      event_location event_city event_state  \
# 0                                    SYMPHONY SPACE   NEW YORK          NY
# 1                                   LABYRINTH BOOKS  Princeton          NJ
# 2  CENTER FOR FICTIONMERCANTILE LIBRARY ASSOC OF NY   BROOKLYN          NY
# 3                                 RIZZOLI BOOKSTORE   NEW YORK          NY
# 4                        Italian Cultural Institute   New York          NY
#
#                         event_description        event_market  \
# 0                 Selected Shorts Reading  NY - New York City
# 1                         In Conversation     NJ - New Jersey
# 2                                   Panel  NY - New York City
# 3                         In Conversation  NY - New York City
# 4  In conversation with Stefano Albertini  NY - New York City
#
#                                                title               authors
# 0  The Penguin Book Of Italian Short Stories (a P...  ['Lahiri', 'Jhumpa']
# 1  The Penguin Book Of Italian Short Stories (a P...  ['Lahiri', 'Jhumpa']
# 2  The Penguin Book Of Italian Short Stories (a P...  ['Lahiri', 'Jhumpa']
# 3  The Penguin Book Of Italian Short Stories (a P...  ['Lahiri', 'Jhumpa']
# 4  The Penguin Book Of Italian Short Stories (a P...  ['Lahiri', 'Jhumpa']

# %%
#transforming merged table to match table in postgres
merged_events = merged_events[['event_id', 'event_source', 'book_id', 'event_participants', 'event_date', 'event_location', 'event_city', 'event_state', 'event_description', 'event_market']]
merged_events = merged_events.rename(columns={'book_id':'event_isbn'})

# %%
#setting index for postgres
merged_events = merged_events.set_index(['event_id'])
merged_events

# %% [markdown]
# # Loading Data to Postgres

# %% [markdown]
# ### Connecting to PostgreSQL

# %%
# Karen's connection

# Connect to Postgres

#database = "booksETL"
#engine = create_engine('postgres://postgres:postgres@localhost:5432/booksETL')
#connection = engine.connect()

# %%
#Andrea's connection

key = b'MOqEgKQI7nsUHaSoom2buW0Hy0qCvVDYaM1-Qp-Db5Q='
cipher_suite = Fernet(key)

with open('Encryptions_PG.bin', 'rb') as file_object:
    for line in file_object:
        encryptedpwd = line
        
uncipher_text = (cipher_suite.decrypt(encryptedpwd))
plain_text_encryptedpassword = bytes(uncipher_text).decode("utf-8") #convert to string

engine = create_engine(f'postgresql://postgres:{plain_text_encryptedpassword}@localhost:5432/booksETL')
connection = engine.connect()

# %%
#Stacey's connection
# Deal with password needed for sql conn
#key = b'R_frnvbIOy25RMAXZtlk5yOn9x6m71YhQnfkpr2QM5w='
# cipher_suite = Fernet(key)

# with open('postgres.bin', 'rb') as file_object:
#     for line in file_object:
#         encryptedpwd = line
        
# uncipher_text = (cipher_suite.decrypt(encryptedpwd))
# pword = bytes(uncipher_text).decode("utf-8")

# engine = create_engine('postgresql://postgres:' + pword + '@localhost:5432/ETL')
# connection = engine.connect()
# engine.table_names()

# %% [markdown]
# ### GOODREADS DATA LOAD

# %%
# Confirm tables

engine.table_names()
# Out:
# ['books', 'events', 'reviews']

# %%
# Load titles into books table

booksDB.to_sql(name='books', con=engine, if_exists='append', index=False)

# %% [markdown]
# ### NYT DATA LOAD

# %%
#NYT DATA LOAD
# Dependent on the Goodreads/BooksDB section 

common_books = booksDB.merge(nyt_books,on=['book_id'])
common_books = common_books[['rank','weeks_on_list', 'book_id', 'publisher', 'book_review_link', 'category', 'current_as_of_date']]
common_books.index.name = 'reviews_id'

common_books.to_sql(name='reviews', con=engine, if_exists='append', index=True)

# %% [markdown]
# ### PENGUIN EVENTS DATA LOAD

# %%
#loading merged PRH events table to DB
merged_events.to_sql(name='events', con = engine, if_exists = 'append', index=False)
